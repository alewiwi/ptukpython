# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(-100,100)
y = x**2

plt.plot(x,y)

# %%
a = np.array([1,2,2,1])
plt.plot(a)

# %% [markdown]
# # The following figure will ksdjfgsdfg
# dfkhgdsjfg
# sdfg.kjdsfhgsdf
# gsdfgksdfgsdfg
# $$x^2$$

# %%
plt.title(" The function y=x^2")
plt.xlabel('X')
plt.ylabel('y')
plt.axis([0,7,0,20])
plt.grid()
plt.plot([1,2,3,4],[1,4,9,16],'g-.',linewidth=4.0)
plt.legend(['X square function'])

# %%
t = np.arange(0,5,0.1)
y1 = np.sin(2*np.pi*t)
y2 = np.sin(2*np.pi*t)
plt.subplot(121)
plt.plot(t,y1,'b-.')
plt.subplot(122)
plt.plot(t,y2,'r--')

# %%
pop = np.random.randint(0,100,100)
pop
# Out:
# array([90, 52, 51, 30, 93,  7,  9, 28, 27, 98, 12, 62, 47, 37, 98, 58, 88,
#        15, 91, 52, 95, 28,  2, 23,  5, 33, 24, 83, 73, 89,  5,  2, 26,  8,
#        59, 58, 27,  8, 22, 10, 26, 58, 77,  7, 94, 92,  1, 31, 11, 74, 37,
#        17, 96, 40, 80, 58,  3, 27, 40, 47, 26, 33, 22,  1, 20, 56, 19, 76,
#        27, 27, 39,  0, 41, 67, 31, 14, 22, 13, 78, 92,  1, 98, 66,  7, 82,
#        71, 80, 73, 65, 55,  4, 84,  7, 92, 51, 35, 54, 13, 63,  3])

# %%
n,bins,patches = plt.hist(pop,bins=5)
plt.grid()

# %%
index = [0,1,2,3,4]
values = [5,7,3,4,6]
plt.bar(index,values,color=['r','g'])
# Out:
# <Container object of 5 artists>

# %%
labels = ['Nokia','Samsung','Apple','Lumia']
values = [10,30,45,15]
colors = ['yellow','green','red','blue']
plt.pie(values,labels=labels,colors=colors)
plt.axis('equal')
# Out:
# (-1.11637372803214,
#  1.1007797090739162,
#  -1.1163737124158366,
#  1.1007797083302826)
